# %%
# set whether normal process or being run by Elsevier supporters
permissions='fulldata' # default or fulldata
# set the project name
project_name = 'test_project_1'  # This is the folder name that you work in, e.g. 'test_project_1'

# %%
# %run /Snippets/header_008
# Out:
# PROJECT DETAILS:
# Project identifier: test_project_1
# Cluster data access level: fulldata
# EXECUTION DETAILS:
# Spark version: 11.3.x-scala2.12,
# Cluster Node Type: i3.xlarge,
# Driver Node Type: c4.2xlarge,
# Worker Node Type: i3.xlarge
# DATA SNAPSHOT DETAILS:
# This notebook uses the latest snapshot date for this version: "v008.20221021151538/", (21 October 2022)
#
#  The following are the Scopus snapshot dates available for datasets at v008:
# ['v008.20220314092239/', 'v008.20220906063204/', 'v008.20221021151538/']
# (If you want to use a different snapshot, in the first cell of your notebook, set the variable `custom_snapshot_date` to one of the options listed above (string data type))
# DATA SAMPLE DETAILS:
# Setting paths to run on full datasets (100% Scopus publication volume)

# %%
import pandas as pd
import numpy as np
import pyspark.pandas as ps
from pyspark.sql import SparkSession
from pyspark.sql.window import Window
from pyspark.sql.functions import monotonically_increasing_id, row_number, coalesce, countDistinct

# %%
# load the datasets
#df_ani = spark.read.format("parquet").load(basePath + tablename_ani)
# EID(long), Year(int), DOI
# Af.affiliation_ids: .select(func.col('Au.email_sha1'))

df_ipr = spark.read.format("parquet").load(basePath + tablename_ipr)
# afid, preferred_name, org_type, postal_code, city, state, country, country_tag

#df_smc_ani = spark.read.format("parquet").load(basePath+tablename_smc_complete)
# EID, subfield_article, subfield_hybrid, subfield_journal

# %% [markdown]
# use the table 'static_data.scival_institutions_20200304' to get additional parent data

# %%
table_scival = table('static_data.scival_institutions_20200304')
df_scival = table_scival.filter(table_scival.country_code=='usa')
df_scival.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>institution_id</th><th>country_num</th><th>name</th><th>region</th><th>inst_type</th><th>latitude</th><th>longitude</th><th>country_code</th><th>affiliation_ids</th></tr></thead><tbody><tr><td>217032</td><td>840</td><td>National Defense University</td><td>NAM</td><td>Academic</td><td>38.866776</td><td>-77.01674</td><td>usa</td><td>List(60021549, 60031754, 60077300)</td></tr><tr><td>508001</td><td>840</td><td>Alabama A and M University</td><td>NAM</td><td>Academic</td><td>34.7839</td><td>-86.5729</td><td>usa</td><td>List(60008740)</td></tr><tr><td>508002</td><td>840</td><td>Albany Medical College</td><td>NAM</td><td>Academic</td><td>42.653</td><td>-73.777</td><td>usa</td><td>List(60007977, 60021390, 108119631)</td></tr><tr><td>508003</td><td>840</td><td>American University Washington DC</td><td>NAM</td><td>Academic</td><td>38.938</td><td>-77.089</td><td>usa</td><td>List(60020420, 60116324)</td></tr><tr><td>508004</td><td>840</td><td>Appalachian State University</td><td>NAM</td><td>Academic</td><td>36.2136</td><td>-81.6843</td><td>usa</td><td>List(60020441)</td></tr><tr><td>508006</td><td>840</td><td>Arizona State University</td><td>NAM</td><td>Academic</td><td>33.609</td><td>-113.56</td><td>usa</td><td>List(60003699, 60003892, 60004372, 60004683, 60009043, 60012562, 60015864, 60086304, 60093724, 60093787, 60093807, 60093810, 60116379, 60116796)</td></tr><tr><td>508007</td><td>840</td><td>Auburn University</td><td>NAM</td><td>Academic</td><td>32.603</td><td>-85.486</td><td>usa</td><td>List(60001085, 60009974, 60010469, 60011754, 60013674, 60018384, 60023694, 60031288, 60075002)</td></tr><tr><td>508008</td><td>840</td><td>Ball State University</td><td>NAM</td><td>Academic</td><td>40.2051</td><td>-85.404</td><td>usa</td><td>List(60028244)</td></tr><tr><td>508009</td><td>840</td><td>Baylor College of Medicine</td><td>NAM</td><td>Academic</td><td>29.711</td><td>-95.397</td><td>usa</td><td>List(60000278, 60001793, 60002441, 60008978, 60009295, 60017203, 60018083, 60027347, 60107844, 60107846, 100750453, 101332385, 115881309)</td></tr><tr><td>508010</td><td>840</td><td>Baylor University</td><td>NAM</td><td>Academic</td><td>31.5487</td><td>-97.1144</td><td>usa</td><td>List(60011278)</td></tr><tr><td>508011</td><td>840</td><td>Boise State University</td><td>NAM</td><td>Academic</td><td>43.6032</td><td>-116.202</td><td>usa</td><td>List(60001456, 60005529)</td></tr><tr><td>508012</td><td>840</td><td>Boston College</td><td>NAM</td><td>Academic</td><td>42.3364</td><td>-71.1675</td><td>usa</td><td>List(60031117)</td></tr><tr><td>508013</td><td>840</td><td>Boston University</td><td>NAM</td><td>Academic</td><td>42.35</td><td>-71.105</td><td>usa</td><td>List(60003526, 60004147, 60006385, 60009611, 60018701, 60019674, 60028144, 60112441, 60116524)</td></tr><tr><td>508014</td><td>840</td><td>Bowling Green State University</td><td>NAM</td><td>Academic</td><td>41.3764</td><td>-83.6237</td><td>usa</td><td>List(60018475)</td></tr><tr><td>508015</td><td>840</td><td>Brandeis University</td><td>NAM</td><td>Academic</td><td>42.366</td><td>-71.259</td><td>usa</td><td>List(60016247, 109637473, 115689368)</td></tr><tr><td>508016</td><td>840</td><td>Brigham Young University</td><td>NAM</td><td>Academic</td><td>40.2545</td><td>-111.648</td><td>usa</td><td>List(60003562, 60003883, 60006832, 60020504, 60116518)</td></tr><tr><td>508017</td><td>840</td><td>Brookhaven National Laboratory</td><td>NAM</td><td>Government</td><td>40.884</td><td>-72.887</td><td>usa</td><td>List(60006221, 60025119)</td></tr><tr><td>508018</td><td>840</td><td>Brown University</td><td>NAM</td><td>Academic</td><td>41.831</td><td>-71.398</td><td>usa</td><td>List(60003486, 60005454, 60009796, 60011460, 60017169, 60021006, 60021025, 60026115, 60028546)</td></tr><tr><td>508019</td><td>840</td><td>Bucknell University</td><td>NAM</td><td>Academic</td><td>40.9526</td><td>-76.8842 ...

# %% [markdown]
# In this table affliation_ids contain the affliation belong to the same institution, we will export this data of this table and manually tagged which afid is the parent of another in this table

# %%
df_scival.count()
# Out:
# Out[11]: 3271

# %%
df_scival_1 = df_scival.select(
    "name", "inst_type", "country_code", func.explode(df_scival.affiliation_ids).alias("afid")
)
df_scival_1.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th
# %%
df_scival_1.count()
# Out:
# Out[13]: 7880

# %%
df_scival_1.select(countDistinct('afid')).show()
# Out:
# +--------------------+
# |count(DISTINCT afid)|
# +--------------------+
# |                7870|
# +--------------------+

# %%
# after distinct count, we can see 7880 become 7870, check this special affid

df_groupby = df_scival_1.groupby('afid').count().withColumnRenamed("afid",'affid')
df_toshow = df_groupby.join(df_scival_1, df_groupby.affid==df_scival_1.afid,"left").drop('afid').groupby(df_groupby.columns).agg(func.collect_set("name").alias('name_list'))
df_toshow.sort('count', ascending=False).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>affid</th><th>count</th><th>name_list</th></tr></thead><tbody><tr><td>60013881</td><td>3</td><td>List(University of Chicago, United States Department of Energy, Fermi National Accelerator Laboratory)</td></tr><tr><td>60018020</td><td>3</td><td>List(Princeton University, United States Department of Energy, Princeton Plasma Physics Laboratory)</td></tr><tr><td>60025590</td><td>3</td><td>List(Stanford University, United States Department of Energy, Stanford Linear Accelerator Center)</td></tr><tr><td>60028609</td><td>3</td><td>List(University of Chicago, Argonne National Laboratory, United States Department of Energy)</td></tr><tr><td>60008417</td><td>2</td><td>List(Beckman Coulter, Danaher)</td></tr><tr><td>60112067</td><td>2</td><td>List(Ultragenyx Pharmaceutical Inc, Ultragenyx Pharmaceutical)</td></tr><tr><td>6000278</td><td>1</td><td>List(Becton, Dickinson and Company)</td></tr><tr><td>6002494</td><td>1</td><td>List(Bausch & Lomb Incorporated)</td></tr><tr><td>60000000</td><td>1</td><td>List(University of California at Davis)</td></tr><tr><td>60000001</td><td>1</td><td>List(Walter Reed Army Institute of Research)</td></tr><tr><td>60000003</td><td>1</td><td>List(Ametek)</td></tr><tr><td>60000009</td><td>1</td><td>List(Villanova University)</td></tr><tr><td>60000018</td><td>1</td><td>List(University of California at Davis)</td></tr><tr><td>60000024</td><td>1</td><td>List(Milliken & Company)</td></tr><tr><td>60000027</td><td>1</td><td>List(KLA-Tencor Corporation)</td></tr><tr><td>60000030</td><td>1</td><td>List(University of Virginia)</td></tr><tr><td>60000037</td><td>1</td><td>List(Baptist Hospital Miami)</td></tr><tr><td>60000041</td><td>1</td><td>List(University of Iowa)</td></tr><tr><td>60000045</td><td>1</td><td>List(Mount Carmel Health System)</td></tr><tr><td>60000052</td><td>1</td><td>List(Vishay)</td></tr><tr><td>60000060</td><td>1</td><td>List(Lehigh University)</td></tr><tr><td>60000071</td><td>1</td><td>List(Calvin College)</td></tr><tr><td>60000076</td><td>1</td><td>List(Children's Hospital Columbus)</td></tr><tr><td>60000092</td><td>1</td><td>List(Louisiana Tech University)</td></tr><tr><td>60000102</td><td>1</td><td>List(Fisk University)</td></tr><tr><td>60000105</td><td>1</td><td>List(Emory University)</td></tr><tr><td>60000118</td><td>1</td><td>List(University of Illinois at Chicago)</td></tr><tr><td>60000128</td><td>1</td><td>List(Mississippi State University)</td></tr><tr><td>60000135</td><td>1</td><td>List(University of North Florida)</td></tr><tr><td>60000141</td><td>1</td><td>List(Monmouth College)</td></tr><tr><td>60000144</td><td>1</td><td>List(Bowdoin College)</td></tr><tr><td>60000149</td><td>1</td><td>List(University of Minnesota)</td></tr><tr><td>60000164</td><td>1</td><td>List(Troy University)</td></tr><tr><td>60000170</td><td>1</td><td>List(Hoffmann-La Roche Inc.)</td></tr><tr><td>60000175</td><td>1</td><td>List(Baptist Health Care)</td></tr><tr><td>60000177</td><td>1</td><td>List(Centers for Disease Control and Prevention)</td></tr><tr><td>60000190</td><td>1</td><td>List(Wal-Mart Stores)</td></tr><tr><td>60000200</td><td>1</td><td>List(American Medical Association)</td></tr><tr><td>60000204</td><td>1</td><td>List(University of Minnesota)</td></tr><tr><td>60000209</td><td>1</td><td>List(University of Connecticut)</td></tr><tr><td>60000213</td><td>1</td><td>List(Rhodes College)</td></tr><tr><td>60000218</td><td>1</td><td>List(University of Hawaii at Mānoa)</td></tr><tr><td>60000221</td><td>1</td><td>List(University of Colorado Boulder)</td></tr><tr><td>60000238</td><td>1</td><td>List(Jackson State University)</td></tr><tr><td>60000247</td><td>1</td><td>List(Cornell University)</td></tr><tr><td>60000248</td><td>1</td><td>List(California State University San Bernardino)</td></tr><tr><td>60000251</td><td>1</td><td>List(IEEE)</td></tr><tr><td>60000253</td><td>1</td><td>List(New York Cit ...

# %%
df_scival_0 = df_scival.select("name","affiliation_ids").withColumn('preferred_name',func.col('name'))
af_data = df_ipr.filter(df_ipr.country_tag=='usa')

# %%
# use the insitution name to try to get the afid in df_ipr which contains afid data
merge_0 = df_scival_0.join(af_data,'preferred_name').select('preferred_name','name','affiliation_ids','afid','postal_code','org_type','parent','parent_preferred_name')
merge_0.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>preferred_name</th><th>name</th><th>affiliation_ids</th><th>afid</th><th>postal_code</th><th>org_type</th><th>parent</th><th>parent_preferred_name</th></tr></thead><tbody><tr><td>National Bureau of Economic Research</td><td>National Bureau of Economic Research</td><td>List(60020337, 114289419)</td><td>103840730</td><td>27858-4353</td><td>null</td><td>60016280</td><td>East Carolina University</td></tr><tr><td>Kennedy and Jenks Consultants</td><td>Kennedy and Jenks Consultants</td><td>List(60096337)</td><td>60096337</td><td>85012</td><td>comp</td><td>null</td><td>null</td></tr><tr><td>American Psychological Association</td><td>American Psychological Association</td><td>List(60012920)</td><td>118346689</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>Texas State University</td><td>Texas State University</td><td>List(60030452)</td><td>60030452</td><td>78666-4684</td><td>univ</td><td>null</td><td>null</td></tr><tr><td>National Research Council</td><td>National Research Council</td><td>List(60009235, 60098160)</td><td>116073221</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>Sealed Air Corporation</td><td>Sealed Air Corporation</td><td>List(60009644)</td><td>122660056</td><td>53177</td><td>null</td><td>null</td><td>null</td></tr><tr><td>National Research Council</td><td>National Research Council</td><td>List(60009235, 60098160)</td><td>100894154</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>